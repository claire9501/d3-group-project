# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import itertools
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %% [markdown]
# ## Generate Cities List

# %%
import numpy as np
#Define our lat/lon range and increments between the range
min_lat = 32
max_lat = 42
min_lon = -114
max_lon = -125
increment = 0.3

#Build our lat/lon list within range
lat_lons = []

lats = [round(num, 2) for num in np.arange(min_lat, max_lat, increment).tolist()]
lons = [round(num, 2) for num in np.arange(min_lon, max_lon, -(increment)).tolist()]
lat_lons = list(itertools.product(lats, lons))
len(lat_lons)
# Out:
# 1258

# %%
# List for holding lat_lngs and cities
cities = []

# Identify nearest city for each lat, lng combination
for lat_lon in lat_lons:
    city = citipy.nearest_city(lat_lon[0], lat_lon[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# %%
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 213

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
appid = weather_api_key

# %%
# base_url = "http://api.openweathermap.org/data/2.5/weather?"
base_url = "http://api.openweathermap.org/data/2.5/onecall/timemachine?"
# base_url = "http://history.openweathermap.org/data/2.5/history/city?"

w_date = "08/07/2020"
w_date_unix = int(time.mktime(datetime.strptime(w_date, "%m/%d/%Y").timetuple()))

counter = 1
city_data = []
cities =[]
for lat_lon in lat_lons:
    params = {
      "lat" : lat_lon[0],
      "lon" : lat_lon[1],
      "dt" : w_date_unix,
      "units" : "imperial",
      "appid" : weather_api_key
       }
    city = citipy.nearest_city(lat_lon[0], lat_lon[1]).city_name
    if city not in cities:
        cities.append(city)
#     try:
    weather = requests.get(base_url, params=params).json()
    lat = weather["lat"]
    lon = weather["lon"]
    temp = weather["current"]["temp"]
#         print(temp)
    humid = weather["current"]["humidity"]
    cloud = weather["current"]["clouds"]
    wind = weather["current"]["wind_speed"]
    date = datetime.fromtimestamp(weather["current"]["dt"]).date()

    city_data.append({"City" : city
                    ,"Latitude" : lat
                    ,"Longitude" : lon
                    ,"Max Temperature": temp
                    ,"Humidity": humid
                    ,"Cloudiness": cloud
                    ,"Wind Speed" : wind
                    ,"Date" : date})

    print(f"Processing Record {counter} - {city}")
    counter = counter + 1
#     except:
#         print("City not found. Skipping")
# Out:
# Processing Record 1 - fortuna foothills
# Processing Record 2 - san luis rio colorado
# Processing Record 3 - estacion coahuila
# Processing Record 4 - estacion coahuila
# Processing Record 5 - estacion coahuila
# Processing Record 6 - delta
# Processing Record 7 - progreso
# Processing Record 8 - ensenada
# Processing Record 9 - ensenada
# Processing Record 10 - el sauzal
# Processing Record 11 - primo tapia
# Processing Record 12 - rosarito
# Processing Record 13 - rosarito
# Processing Record 14 - rosarito
# Processing Record 15 - rosarito
# Processing Record 16 - coronado
# Processing Record 17 - coronado
# Processing Record 18 - rancho palos verdes
# Processing Record 19 - rancho palos verdes
# Processing Record 20 - rancho palos verdes
# Processing Record 21 - port hueneme
# Processing Record 22 - port hueneme
# Processing Record 23 - isla vista
# Processing Record 24 - isla vista
# Processing Record 25 - lompoc
# Processing Record 26 - lompoc
# Processing Record 27 - lompoc
# Processing Record 28 - lompoc
# Processing Record 29 - lompoc
# Processing Record 30 - lompoc
# Processing Record 31 - lompoc
# Processing Record 32 - lompoc
# Processing Record 33 - lompoc
# Processing Record 34 - lompoc
# Processing Record 35 - lompoc
# Processing Record 36 - lompoc
# Processing Record 37 - lompoc
# Processing Record 38 - fortuna foothills
# Processing Record 39 - fortuna foothills
# Processing Record 40 - san luis rio colorado
# Processing Record 41 - estacion coahuila
# Processing Record 42 - delta
# Processing Record 43 - progreso
# Processing Record 44 - progreso
# Processing Record 45 - la joya
# Processing Record 46 - la joya
# Processing Record 47 - primo tapia
# Processing Record 48 - rosarito
# Processing Record 49 - rosarito
# Processing Record 50 - imperial beach
# Processing Record 51 - coronado
# Processing Record 52 - coronado
# Processing Record 53 - coronado
# Processing Record 54 - rancho palos verdes
# Processing Record 55 - rancho palos verdes
# Processing Record 56 - rancho palos verdes
# Processing Record 57 - port hueneme
# Processing Record 58 - port hueneme
# Processing Record 59 - port hueneme
# Processing Record 60 - isla vista
# Processing Record 61 - isla vista
# Processing Record 62 - lompoc
# Processing Record 63 - lompoc
# Processing Record 64 - lompoc
# Processing Record 65 - lompoc
# Processing Record 66 - lompoc
# Processing Record 67 - lompoc
# Processing Record 68 - lompoc
# Processing Record 69 - lompoc
# Processing Record 70 - lompoc
# Processing Record 71 - lompoc
# Processing Record 72 - lompoc
# Processing Record 73 - lompoc
# Processing Record 74 - lompoc
# Processing Record 75 - fortuna foothills
# Processing Record 76 - fortuna foothills
# Processing Record 77 - somerton
# Processing Record 78 - ejido hermosillo
# Processing Record 79 - puebla
# Processing Record 80 - mexicali
# Processing Record 81 - progreso
# Processing Record 82 - progreso
# Processing Record 83 - la joya
# Processing Record 84 - tecate
# Processing Record 85 - bonita
# Processing Record 86 - coronado
# Processing Record 87 - coronado
# Processing Record 88 - coronado
# Processing Record 89 - dana point
# Processing Record 90 - rancho palos verdes
# Processing Record 91 - rancho palos verdes
# Processing Record 92 - rancho palos verdes
# Processing Record 93 - malibu
# Processing Record 94 - port hueneme
# Processing Record 95 - port hueneme
# Processing Record 96 - isla vista
# Processing Record 97 - isla vista
# Processing Record 98 - lompoc
# Processing Record 99 - lompoc
# Processing Record 100 - lompoc
# Processing Record 101 - lompoc
# Processing Record 102 - lompoc
# Processing Record 103 - lompoc
# Processing Record 104 - lompoc
# Processing Record 105 - lompoc
# Processing Record 106 - lompoc
# Processing Record 107 - lompoc
# Processing Record 108 - lompoc
# Processing Record 109 - lompoc
# Processing Record 110 - lompoc
# Processing Record 111 - lompoc
# Processing Record 112 - fortuna foothills
# Processing Record 113 - fortuna foothills
# Processing Record 114 - yuma
# Processing Record 115 - algodones
# Processing Record 116 - brawley
# Processing Record 117 - brawley
# Processing Record 118 - imperial
# Processing Record 119 - imperial
# Processing Record 120 - alpine
# Processing Record 121 - alpine
# Processing Record 122 - santee
# Processing Record 123 - solana beach
# Processing Record 124 - encinitas
# Processing Record 125 - oceanside
# Processing Record 126 - dana point
# Processing Record 127 - rancho palos verdes
# Processing Record 128 - rancho palos verdes
# Processing Record 129 - rancho palos verdes
# Processing Record 130 - malibu
# Processing Record 131 - port hueneme
# Processing Record 132 - port hueneme
# Processing Record 133 - isla vista
# Processing Record 134 - isla vista
# Processing Record 135 - lompoc
# Processing Record 136 - lompoc
# Processing Record 137 - lompoc
# Processing Record 138 - lompoc
# Processing Record 139 - lompoc
# Processing Record 140 - lompoc
# Processing Record 141 - lompoc
# Processing Record 142 - lompoc
# Processing Record 143 - lompoc
# Processing Record 144 - lompoc
# Processing Record 145 - lompoc
# Processing Record 146 - lompoc
# Processing Record 147 - lompoc
# Processing Record 148 - morro bay
# Processing Record 149 - fortuna foothills
# Processing Record 150 - blythe
# Processing Record 151 - blythe
# Processing Record 152 - blythe
# Processing Record 153 - brawley
# Processing Record 154 - brawley
# Processing Record 155 - brawley
# Processing Record 156 - coachella
# Processing Record 157 - la quinta
# Processing Record 158 - ramona
# Processing Record 159 - escondido
# Processing Record 160 - vista
# Processing Record 161 - oceanside
# Processing Record 162 - dana point
# Processing Record 163 - newport beach
# Processing Record 164 - rancho palos verdes
# Processing Record 165 - rancho palos verdes
# Processing Record 166 - malibu
# Processing Record 167 - port hueneme
# Processing Record 168 - port hueneme
# Processing Record 169 - isla vista
# Processing Record 170 - isla vista
# Processing Record 171 - isla vista
# Processing Record 172 - lompoc
# Processing Record 173 - lompoc
# Processing Record 174 - lompoc
# Processing Record 175 - lompoc
# Processing Record 176 - lompoc
# Processing Record 177 - lompoc
# Processing Record 178 - lompoc
# Processing Record 179 - lompoc
# Processing Record 180 - lompoc
# Processing Record 181 - lompoc
# Processing Record 182 - lompoc
# Processing Record 183 - morro bay
# Processing Record 184 - morro bay
# Processing Record 185 - pacific grove
# Processing Record 186 - blythe
# Processing Record 187 - blythe
# Processing Record 188 - blythe
# Processing Record 189 - blythe
# Processing Record 190 - blythe
# Processing Record 191 - brawley
# Processing Record 192 - coachella
# Processing Record 193 - coachella
# Processing Record 194 - la quinta
# Processing Record 195 - east hemet
# Processing Record 196 - temecula
# Processing Record 197 - wildomar
# Processing Record 198 - san juan capistrano
# Processing Record 199 - newport beach
# Processing Record 200 - huntington beach
# Processing Record 201 - rancho palos verdes
# Processing Record 202 - rancho palos verdes
# Processing Record 203 - malibu
# Processing Record 204 - port hueneme
# Processing Record 205 - port hueneme
# Processing Record 206 - isla vista
# Processing Record 207 - isla vista
# Processing Record 208 - lompoc
# Processing Record 209 - lompoc
# Processing Record 210 - lompoc
# Processing Record 211 - lompoc
# Processing Record 212 - lompoc
# Processing Record 213 - lompoc
# Processing Record 214 - lompoc
# Processing Record 215 - lompoc
# Processing Record 216 - lompoc
# Processing Record 217 - lompoc
# Processing Record 218 - morro bay
# Processing Record 219 - morro bay
# Processing Record 220 - morro bay
# Processing Record 221 - pacific grove
# Processing Record 222 - pacific grove
# Processing Record 223 - blythe
# Processing Record 224 - blythe
# Processing Record 225 - blythe
# Processing Record 226 - blythe
# Processing Record 227 - blythe
# Processing Record 228 - twentynine palms
# Processing Record 229 - coachella
# Processing Record 230 - indio
# Processing Record 231 - rancho mirage
# Processing Record 232 - palm springs
# Processing Record 233 - san jacinto
# Processing Record 234 - perris
# Processing Record 235 - corona
# Processing Record 236 - anaheim
# Processing Record 237 - signal hill
# Processing Record 238 - palos verdes estates
# Processing Record 239 - malibu
# Processing Record 240 - malibu
# Processing Record 241 - port hueneme
# Processing Record 242 - port hueneme
# Processing Record 243 - isla vista
# Processing Record 244 - isla vista
# Processing Record 245 - lompoc
# Processing Record 246 - lompoc
# Processing Record 247 - lompoc
# Processing Record 248 - lompoc
# Processing Record 249 - lompoc
# Processing Record 250 - lompoc
# Processing Record 251 - lompoc
# Processing Record 252 - lompoc
# Processing Record 253 - morro bay
# Processing Record 254 - morro bay
# Processing Record 255 - morro bay
# Processing Record 256 - morro bay
# Processing Record 257 - pacific grove
# Processing Record 258 - pacific grove
# Processing Record 259 - pacific grove
# Processing Record 260 - lake havasu city
# Processing Record 261 - lake havasu city
# Processing Record 262 - lake havasu city
# Processing Record 263 - blythe
# Processing Record 264 - blythe
# Processing Record 265 - twentynine palms
# Processing Record 266 - twentynine palms
# Processing Record 267 - twentynine palms
# Processing Record 268 - yucca valley
# Processing Record 269 - desert hot springs
# Processing Record 270 - yucaipa
# Processing Record 271 - san bernardino
# Processing Record 272 - rancho cucamonga
# Processing Record 273 - covina
# Processing Record 274 - south pasadena
# Processing Record 275 - santa monica
# Processing Record 276 - agoura hills
# Processing Record 277 - port hueneme
# Processing Record 278 - port hueneme
# Processing Record 279 - santa barbara
# Processing Record 280 - isla vista
# Processing Record 281 - isla vista
# Processing Record 282 - lompoc
# Processing Record 283 - lompoc
# Processing Record 284 - lompoc
# Processing Record 285 - lompoc
# Processing Record 286 - lompoc
# Processing Record 287 - lompoc
# Processing Record 288 - morro bay
# Processing Record 289 - morro bay
# Processing Record 290 - morro bay
# Processing Record 291 - morro bay
# Processing Record 292 - monterey
# Processing Record 293 - monterey
# Processing Record 294 - pacific grove
# Processing Record 295 - pacific grove
# Processing Record 296 - pacific grove
# Processing Record 297 - lake havasu city
# Processing Record 298 - lake havasu city
# Processing Record 299 - lake havasu city
# Processing Record 300 - lake havasu city
# Processing Record 301 - lake havasu city
# Processing Record 302 - twentynine palms
# Processing Record 303 - twentynine palms
# Processing Record 304 - twentynine palms
# Processing Record 305 - yucca valley
# Processing Record 306 - yucca valley
# Processing Record 307 - apple valley
# Processing Record 308 - hesperia
# Processing Record 309 - adelanto
# Processing Record 310 - glendora
# Processing Record 311 - palmdale
# Processing Record 312 - santa clarita
# Processing Record 313 - fillmore
# Processing Record 314 - santa paula
# Processing Record 315 - carpinteria
# Processing Record 316 - santa barbara
# Processing Record 317 - isla vista
# Processing Record 318 - lompoc
# Processing Record 319 - lompoc
# Processing Record 320 - lompoc
# Processing Record 321 - lompoc
# Processing Record 322 - lompoc
# Processing Record 323 - morro bay
# Processing Record 324 - morro bay
# Processing Record 325 - morro bay
# Processing Record 326 - morro bay
# Processing Record 327 - morro bay
# Processing Record 328 - monterey
# Processing Record 329 - monterey
# Processing Record 330 - pacific grove
# Processing Record 331 - pacific grove
# Processing Record 332 - pacific grove
# Processing Record 333 - pacific grove
# Processing Record 334 - lake havasu city
# Processing Record 335 - lake havasu city
# Processing Record 336 - lake havasu city
# Processing Record 337 - bullhead city
# Processing Record 338 - bullhead city
# Processing Record 339 - twentynine palms
# Processing Record 340 - twentynine palms
# Processing Record 341 - twentynine palms
# Processing Record 342 - yucca valley
# Processing Record 343 - barstow
# Processing Record 344 - barstow
# Processing Record 345 - adelanto
# Processing Record 346 - adelanto
# Processing Record 347 - lancaster
# Processing Record 348 - quartz hill
# Processing Record 349 - quartz hill
# Processing Record 350 - fillmore
# Processing Record 351 - santa paula
# Processing Record 352 - carpinteria
# Processing Record 353 - santa barbara
# Processing Record 354 - goleta
# Processing Record 355 - lompoc
# Processing Record 356 - lompoc
# Processing Record 357 - lompoc
# Processing Record 358 - pismo beach
# Processing Record 359 - morro bay
# Processing Record 360 - morro bay
# Processing Record 361 - morro bay
# Processing Record 362 - morro bay
# Processing Record 363 - morro bay
# Processing Record 364 - monterey
# Processing Record 365 - monterey
# Processing Record 366 - pacific grove
# Processing Record 367 - pacific grove
# Processing Record 368 - pacific grove
# Processing Record 369 - pacific grove
# Processing Record 370 - pacific grove
# Processing Record 371 - kingman
# Processing Record 372 - bullhead city
# Processing Record 373 - bullhead city
# Processing Record 374 - bullhead city
# Processing Record 375 - bullhead city
# Processing Record 376 - bullhead city
# Processing Record 377 - twentynine palms
# Processing Record 378 - twentynine palms
# Processing Record 379 - barstow
# Processing Record 380 - barstow
# Processing Record 381 - barstow
# Processing Record 382 - barstow
# Processing Record 383 - california city
# Processing Record 384 - california city
# Processing Record 385 - california city
# Processing Record 386 - tehachapi
# Processing Record 387 - arvin
# Processing Record 388 - lamont
# Processing Record 389 - taft
# Processing Record 390 - taft
# Processing Record 391 - santa maria
# Processing Record 392 - santa maria
# Processing Record 393 - arroyo grande
# Processing Record 394 - pismo beach
# Processing Record 395 - morro bay
# Processing Record 396 - morro bay
# Processing Record 397 - morro bay
# Processing Record 398 - morro bay
# Processing Record 399 - morro bay
# Processing Record 400 - monterey
# Processing Record 401 - monterey
# Processing Record 402 - pacific grove
# Processing Record 403 - pacific grove
# Processing Record 404 - pacific grove
# Processing Record 405 - pacific grove
# Processing Record 406 - pacific grove
# Processing Record 407 - pacific grove
# Processing Record 408 - kingman
# Processing Record 409 - kingman
# Processing Record 410 - bullhead city
# Processing Record 411 - bullhead city
# Processing Record 412 - bullhead city
# Processing Record 413 - spring valley
# Processing Record 414 - pahrump
# Processing Record 415 - pahrump
# Processing Record 416 - barstow
# Processing Record 417 - barstow
# Processing Record 418 - barstow
# Processing Record 419 - barstow
# Processing Record 420 - ridgecrest
# Processing Record 421 - california city
# Processing Record 422 - california city
# Processing Record 423 - tehachapi
# Processing Record 424 - arvin
# Processing Record 425 - bakersfield
# Processing Record 426 - taft
# Processing Record 427 - taft
# Processing Record 428 - santa maria
# Processing Record 429 - arroyo grande
# Processing Record 430 - san luis obispo
# Processing Record 431 - morro bay
# Processing Record 432 - morro bay
# Processing Record 433 - morro bay
# Processing Record 434 - morro bay
# Processing Record 435 - morro bay
# Processing Record 436 - monterey
# Processing Record 437 - monterey
# Processing Record 438 - pacific grove
# Processing Record 439 - pacific grove
# Processing Record 440 - pacific grove
# Processing Record 441 - pacific grove
# Processing Record 442 - pacific grove
# Processing Record 443 - pacific grove
# Processing Record 444 - pacific grove
# Processing Record 445 - kingman
# Processing Record 446 - kingman
# Processing Record 447 - boulder city
# Processing Record 448 - boulder city
# Processing Record 449 - henderson
# Processing Record 450 - spring valley
# Processing Record 451 - pahrump
# Processing Record 452 - pahrump
# Processing Record 453 - pahrump
# Processing Record 454 - barstow
# Processing Record 455 - ridgecrest
# Processing Record 456 - ridgecrest
# Processing Record 457 - ridgecrest
# Processing Record 458 - ridgecrest
# Processing Record 459 - california city
# Processing Record 460 - tehachapi
# Processing Record 461 - oildale
# Processing Record 462 - shafter
# Processing Record 463 - wasco
# Processing Record 464 - wasco
# Processing Record 465 - avenal
# Processing Record 466 - atascadero
# Processing Record 467 - atascadero
# Processing Record 468 - morro bay
# Processing Record 469 - morro bay
# Processing Record 470 - morro bay
# Processing Record 471 - greenfield
# Processing Record 472 - monterey
# Processing Record 473 - monterey
# Processing Record 474 - monterey
# Processing Record 475 - pacific grove
# Processing Record 476 - pacific grove
# Processing Record 477 - pacific grove
# Processing Record 478 - pacific grove
# Processing Record 479 - pacific grove
# Processing Record 480 - pacific grove
# Processing Record 481 - half moon bay
# Processing Record 482 - kingman
# Processing Record 483 - boulder city
# Processing Record 484 - boulder city
# Processing Record 485 - boulder city
# Processing Record 486 - paradise
# Processing Record 487 - spring valley
# Processing Record 488 - pahrump
# Processing Record 489 - pahrump
# Processing Record 490 - pahrump
# Processing Record 491 - pahrump
# Processing Record 492 - ridgecrest
# Processing Record 493 - ridgecrest
# Processing Record 494 - ridgecrest
# Processing Record 495 - ridgecrest
# Processing Record 496 - ridgecrest
# Processing Record 497 - porterville
# Processing Record 498 - porterville
# Processing Record 499 - porterville
# Processing Record 500 - delano
# Processing Record 501 - corcoran
# Processing Record 502 - avenal
# Processing Record 503 - avenal
# Processing Record 504 - coalinga
# Processing Record 505 - king city
# Processing Record 506 - king city
# Processing Record 507 - king city
# Processing Record 508 - greenfield
# Processing Record 509 - monterey
# Processing Record 510 - monterey
# Processing Record 511 - pacific grove
# Processing Record 512 - pacific grove
# Processing Record 513 - pacific grove
# Processing Record 514 - pacific grove
# Processing Record 515 - pacific grove
# Processing Record 516 - half moon bay
# Processing Record 517 - half moon bay
# Processing Record 518 - half moon bay
# Processing Record 519 - boulder city
# Processing Record 520 - boulder city
# Processing Record 521 - boulder city
# Processing Record 522 - sunrise manor
# Processing Record 523 - las vegas
# Processing Record 524 - spring valley
# Processing Record 525 - pahrump
# Processing Record 526 - pahrump
# Processing Record 527 - pahrump
# Processing Record 528 - pahrump
# Processing Record 529 - ridgecrest
# Processing Record 530 - ridgecrest
# Processing Record 531 - ridgecrest
# Processing Record 532 - ridgecrest
# Processing Record 533 - ridgecrest
# Processing Record 534 - porterville
# Processing Record 535 - porterville
# Processing Record 536 - lindsay
# Processing Record 537 - tulare
# Processing Record 538 - lemoore
# Processing Record 539 - avenal
# Processing Record 540 - coalinga
# Processing Record 541 - coalinga
# Processing Record 542 - king city
# Processing Record 543 - king city
# Processing Record 544 - greenfield
# Processing Record 545 - monterey
# Processing Record 546 - monterey
# Processing Record 547 - pacific grove
# Processing Record 548 - pacific grove
# Processing Record 549 - pacific grove
# Processing Record 550 - pacific grove
# Processing Record 551 - half moon bay
# Processing Record 552 - half moon bay
# Processing Record 553 - half moon bay
# Processing Record 554 - half moon bay
# Processing Record 555 - half moon bay
# Processing Record 556 - saint george
# Processing Record 557 - boulder city
# Processing Record 558 - sunrise manor
# Processing Record 559 - sunrise manor
# Processing Record 560 - north las vegas
# Processing Record 561 - spring valley
# Processing Record 562 - pahrump
# Processing Record 563 - pahrump
# Processing Record 564 - pahrump
# Processing Record 565 - pahrump
# Processing Record 566 - pahrump
# Processing Record 567 - ridgecrest
# Processing Record 568 - ridgecrest
# Processing Record 569 - ridgecrest
# Processing Record 570 - porterville
# Processing Record 571 - lindsay
# Processing Record 572 - exeter
# Processing Record 573 - exeter
# Processing Record 574 - dinuba
# Processing Record 575 - selma
# Processing Record 576 - kerman
# Processing Record 577 - mendota
# Processing Record 578 - mendota
# Processing Record 579 - king city
# Processing Record 580 - soledad
# Processing Record 581 - gonzales
# Processing Record 582 - seaside
# Processing Record 583 - pacific grove
# Processing Record 584 - pacific grove
# Processing Record 585 - pacific grove
# Processing Record 586 - santa cruz
# Processing Record 587 - half moon bay
# Processing Record 588 - half moon bay
# Processing Record 589 - half moon bay
# Processing Record 590 - half moon bay
# Processing Record 591 - half moon bay
# Processing Record 592 - half moon bay
# Processing Record 593 - saint george
# Processing Record 594 - saint george
# Processing Record 595 - sunrise manor
# Processing Record 596 - sunrise manor
# Processing Record 597 - sunrise manor
# Processing Record 598 - north las vegas
# Processing Record 599 - pahrump
# Processing Record 600 - pahrump
# Processing Record 601 - pahrump
# Processing Record 602 - pahrump
# Processing Record 603 - pahrump
# Processing Record 604 - ridgecrest
# Processing Record 605 - ridgecrest
# Processing Record 606 - ridgecrest
# Processing Record 607 - exeter
# Processing Record 608 - exeter
# Processing Record 609 - orange cove
# Processing Record 610 - orange cove
# Processing Record 611 - sanger
# Processing Record 612 - clovis
# Processing Record 613 - kerman
# Processing Record 614 - mendota
# Processing Record 615 - mendota
# Processing Record 616 - los banos
# Processing Record 617 - hollister
# Processing Record 618 - hollister
# Processing Record 619 - marina
# Processing Record 620 - santa cruz
# Processing Record 621 - santa cruz
# Processing Record 622 - santa cruz
# Processing Record 623 - half moon bay
# Processing Record 624 - half moon bay
# Processing Record 625 - half moon bay
# Processing Record 626 - half moon bay
# Processing Record 627 - half moon bay
# Processing Record 628 - pacifica
# Processing Record 629 - pacifica
# Processing Record 630 - saint george
# Processing Record 631 - saint george
# Processing Record 632 - sunrise manor
# Processing Record 633 - sunrise manor
# Processing Record 634 - sunrise manor
# Processing Record 635 - north las vegas
# Processing Record 636 - pahrump
# Processing Record 637 - pahrump
# Processing Record 638 - pahrump
# Processing Record 639 - pahrump
# Processing Record 640 - pahrump
# Processing Record 641 - ridgecrest
# Processing Record 642 - ridgecrest
# Processing Record 643 - exeter
# Processing Record 644 - orange cove
# Processing Record 645 - orange cove
# Processing Record 646 - orange cove
# Processing Record 647 - orange cove
# Processing Record 648 - clovis
# Processing Record 649 - clovis
# Processing Record 650 - madera
# Processing Record 651 - chowchilla
# Processing Record 652 - merced
# Processing Record 653 - los banos
# Processing Record 654 - hollister
# Processing Record 655 - gilroy
# Processing Record 656 - morgan hill
# Processing Record 657 - scotts valley
# Processing Record 658 - half moon bay
# Processing Record 659 - half moon bay
# Processing Record 660 - half moon bay
# Processing Record 661 - half moon bay
# Processing Record 662 - pacifica
# Processing Record 663 - pacifica
# Processing Record 664 - pacifica
# Processing Record 665 - pacifica
# Processing Record 666 - pacifica
# Processing Record 667 - saint george
# Processing Record 668 - saint george
# Processing Record 669 - saint george
# Processing Record 670 - sunrise manor
# Processing Record 671 - sunrise manor
# Processing Record 672 - north las vegas
# Processing Record 673 - pahrump
# Processing Record 674 - pahrump
# Processing Record 675 - pahrump
# Processing Record 676 - pahrump
# Processing Record 677 - pahrump
# Processing Record 678 - pahrump
# Processing Record 679 - ridgecrest
# Processing Record 680 - orange cove
# Processing Record 681 - orange cove
# Processing Record 682 - orange cove
# Processing Record 683 - orange cove
# Processing Record 684 - orange cove
# Processing Record 685 - clovis
# Processing Record 686 - madera
# Processing Record 687 - chowchilla
# Processing Record 688 - merced
# Processing Record 689 - atwater
# Processing Record 690 - turlock
# Processing Record 691 - patterson
# Processing Record 692 - morgan hill
# Processing Record 693 - east foothills
# Processing Record 694 - los altos
# Processing Record 695 - half moon bay
# Processing Record 696 - half moon bay
# Processing Record 697 - pacifica
# Processing Record 698 - pacifica
# Processing Record 699 - pacifica
# Processing Record 700 - pacifica
# Processing Record 701 - pacifica
# Processing Record 702 - mill valley
# Processing Record 703 - healdsburg
# Processing Record 704 - saint george
# Processing Record 705 - saint george
# Processing Record 706 - saint george
# Processing Record 707 - saint george
# Processing Record 708 - sunrise manor
# Processing Record 709 - sunrise manor
# Processing Record 710 - pahrump
# Processing Record 711 - pahrump
# Processing Record 712 - pahrump
# Processing Record 713 - pahrump
# Processing Record 714 - pahrump
# Processing Record 715 - pahrump
# Processing Record 716 - orange cove
# Processing Record 717 - orange cove
# Processing Record 718 - orange cove
# Processing Record 719 - orange cove
# Processing Record 720 - orange cove
# Processing Record 721 - clovis
# Processing Record 722 - clovis
# Processing Record 723 - chowchilla
# Processing Record 724 - merced
# Processing Record 725 - merced
# Processing Record 726 - oakdale
# Processing Record 727 - riverbank
# Processing Record 728 - ripon
# Processing Record 729 - tracy
# Processing Record 730 - livermore
# Processing Record 731 - ashland
# Processing Record 732 - south san francisco
# Processing Record 733 - pacifica
# Processing Record 734 - mill valley
# Processing Record 735 - mill valley
# Processing Record 736 - san anselmo
# Processing Record 737 - rohnert park
# Processing Record 738 - healdsburg
# Processing Record 739 - healdsburg
# Processing Record 740 - healdsburg
# Processing Record 741 - saint george
# Processing Record 742 - saint george
# Processing Record 743 - saint george
# Processing Record 744 - saint george
# Processing Record 745 - sunrise manor
# Processing Record 746 - sunrise manor
# Processing Record 747 - pahrump
# Processing Record 748 - pahrump
# Processing Record 749 - pahrump
# Processing Record 750 - pahrump
# Processing Record 751 - pahrump
# Processing Record 752 - fallon
# Processing Record 753 - fallon
# Processing Record 754 - fallon
# Processing Record 755 - fallon
# Processing Record 756 - fallon
# Processing Record 757 - orange cove
# Processing Record 758 - south lake tahoe
# Processing Record 759 - south lake tahoe
# Processing Record 760 - south lake tahoe
# Processing Record 761 - merced
# Processing Record 762 - oakdale
# Processing Record 763 - oakdale
# Processing Record 764 - oakdale
# Processing Record 765 - garden acres
# Processing Record 766 - country club
# Processing Record 767 - antioch
# Processing Record 768 - martinez
# Processing Record 769 - san pablo
# Processing Record 770 - san anselmo
# Processing Record 771 - petaluma
# Processing Record 772 - rohnert park
# Processing Record 773 - healdsburg
# Processing Record 774 - healdsburg
# Processing Record 775 - healdsburg
# Processing Record 776 - ukiah
# Processing Record 777 - ukiah
# Processing Record 778 - cedar city
# Processing Record 779 - cedar city
# Processing Record 780 - saint george
# Processing Record 781 - saint george
# Processing Record 782 - saint george
# Processing Record 783 - sunrise manor
# Processing Record 784 - pahrump
# Processing Record 785 - pahrump
# Processing Record 786 - pahrump
# Processing Record 787 - pahrump
# Processing Record 788 - fallon
# Processing Record 789 - fallon
# Processing Record 790 - fallon
# Processing Record 791 - fallon
# Processing Record 792 - fallon
# Processing Record 793 - fallon
# Processing Record 794 - fallon
# Processing Record 795 - south lake tahoe
# Processing Record 796 - south lake tahoe
# Processing Record 797 - south lake tahoe
# Processing Record 798 - south lake tahoe
# Processing Record 799 - placerville
# Processing Record 800 - placerville
# Processing Record 801 - cameron park
# Processing Record 802 - galt
# Processing Record 803 - elk grove
# Processing Record 804 - dixon
# Processing Record 805 - fairfield
# Processing Record 806 - sonoma
# Processing Record 807 - rohnert park
# Processing Record 808 - roseland
# Processing Record 809 - healdsburg
# Processing Record 810 - healdsburg
# Processing Record 811 - healdsburg
# Processing Record 812 - ukiah
# Processing Record 813 - ukiah
# Processing Record 814 - ukiah
# Processing Record 815 - cedar city
# Processing Record 816 - cedar city
# Processing Record 817 - cedar city
# Processing Record 818 - saint george
# Processing Record 819 - saint george
# Processing Record 820 - elko
# Processing Record 821 - elko
# Processing Record 822 - elko
# Processing Record 823 - elko
# Processing Record 824 - fallon
# Processing Record 825 - fallon
# Processing Record 826 - fallon
# Processing Record 827 - fallon
# Processing Record 828 - fallon
# Processing Record 829 - fallon
# Processing Record 830 - fallon
# Processing Record 831 - fallon
# Processing Record 832 - carson city
# Processing Record 833 - south lake tahoe
# Processing Record 834 - south lake tahoe
# Processing Record 835 - south lake tahoe
# Processing Record 836 - south lake tahoe
# Processing Record 837 - placerville
# Processing Record 838 - cameron park
# Processing Record 839 - folsom
# Processing Record 840 - sacramento
# Processing Record 841 - davis
# Processing Record 842 - vacaville
# Processing Record 843 - sonoma
# Processing Record 844 - windsor
# Processing Record 845 - healdsburg
# Processing Record 846 - healdsburg
# Processing Record 847 - ukiah
# Processing Record 848 - ukiah
# Processing Record 849 - ukiah
# Processing Record 850 - ukiah
# Processing Record 851 - ukiah
# Processing Record 852 - cedar city
# Processing Record 853 - cedar city
# Processing Record 854 - west wendover
# Processing Record 855 - west wendover
# Processing Record 856 - elko
# Processing Record 857 - elko
# Processing Record 858 - elko
# Processing Record 859 - elko
# Processing Record 860 - elko
# Processing Record 861 - elko
# Processing Record 862 - fallon
# Processing Record 863 - fallon
# Processing Record 864 - fallon
# Processing Record 865 - fallon
# Processing Record 866 - fallon
# Processing Record 867 - fallon
# Processing Record 868 - fallon
# Processing Record 869 - fallon
# Processing Record 870 - carson city
# Processing Record 871 - carson city
# Processing Record 872 - south lake tahoe
# Processing Record 873 - south lake tahoe
# Processing Record 874 - placerville
# Processing Record 875 - auburn
# Processing Record 876 - lincoln
# Processing Record 877 - olivehurst
# Processing Record 878 - woodland
# Processing Record 879 - woodland
# Processing Record 880 - clearlake
# Processing Record 881 - clearlake
# Processing Record 882 - healdsburg
# Processing Record 883 - ukiah
# Processing Record 884 - ukiah
# Processing Record 885 - ukiah
# Processing Record 886 - ukiah
# Processing Record 887 - ukiah
# Processing Record 888 - ukiah
# Processing Record 889 - west wendover
# Processing Record 890 - west wendover
# Processing Record 891 - west wendover
# Processing Record 892 - west wendover
# Processing Record 893 - elko
# Processing Record 894 - elko
# Processing Record 895 - elko
# Processing Record 896 - elko
# Processing Record 897 - elko
# Processing Record 898 - elko
# Processing Record 899 - fallon
# Processing Record 900 - fallon
# Processing Record 901 - fallon
# Processing Record 902 - fallon
# Processing Record 903 - fallon
# Processing Record 904 - fallon
# Processing Record 905 - fallon
# Processing Record 906 - fallon
# Processing Record 907 - carson city
# Processing Record 908 - carson city
# Processing Record 909 - truckee
# Processing Record 910 - truckee
# Processing Record 911 - truckee
# Processing Record 912 - grass valley
# Processing Record 913 - grass valley
# Processing Record 914 - linda
# Processing Record 915 - south yuba city
# Processing Record 916 - south yuba city
# Processing Record 917 - clearlake
# Processing Record 918 - clearlake
# Processing Record 919 - ukiah
# Processing Record 920 - ukiah
# Processing Record 921 - ukiah
# Processing Record 922 - ukiah
# Processing Record 923 - ukiah
# Processing Record 924 - ukiah
# Processing Record 925 - fortuna
# Processing Record 926 - west wendover
# Processing Record 927 - west wendover
# Processing Record 928 - west wendover
# Processing Record 929 - west wendover
# Processing Record 930 - elko
# Processing Record 931 - elko
# Processing Record 932 - elko
# Processing Record 933 - elko
# Processing Record 934 - elko
# Processing Record 935 - elko
# Processing Record 936 - winnemucca
# Processing Record 937 - fallon
# Processing Record 938 - fallon
# Processing Record 939 - fallon
# Processing Record 940 - fallon
# Processing Record 941 - fallon
# Processing Record 942 - fallon
# Processing Record 943 - fernley
# Processing Record 944 - fernley
# Processing Record 945 - sparks
# Processing Record 946 - reno
# Processing Record 947 - truckee
# Processing Record 948 - truckee
# Processing Record 949 - grass valley
# Processing Record 950 - grass valley
# Processing Record 951 - oroville
# Processing Record 952 - chico
# Processing Record 953 - chico
# Processing Record 954 - clearlake
# Processing Record 955 - clearlake
# Processing Record 956 - ukiah
# Processing Record 957 - ukiah
# Processing Record 958 - ukiah
# Processing Record 959 - ukiah
# Processing Record 960 - ukiah
# Processing Record 961 - fortuna
# Processing Record 962 - fortuna
# Processing Record 963 - west wendover
# Processing Record 964 - west wendover
# Processing Record 965 - west wendover
# Processing Record 966 - west wendover
# Processing Record 967 - elko
# Processing Record 968 - elko
# Processing Record 969 - elko
# Processing Record 970 - elko
# Processing Record 971 - elko
# Processing Record 972 - elko
# Processing Record 973 - winnemucca
# Processing Record 974 - winnemucca
# Processing Record 975 - winnemucca
# Processing Record 976 - fallon
# Processing Record 977 - fallon
# Processing Record 978 - fallon
# Processing Record 979 - fallon
# Processing Record 980 - fernley
# Processing Record 981 - fernley
# Processing Record 982 - sun valley
# Processing Record 983 - sun valley
# Processing Record 984 - truckee
# Processing Record 985 - susanville
# Processing Record 986 - grass valley
# Processing Record 987 - magalia
# Processing Record 988 - magalia
# Processing Record 989 - chico
# Processing Record 990 - chico
# Processing Record 991 - red bluff
# Processing Record 992 - red bluff
# Processing Record 993 - ukiah
# Processing Record 994 - ukiah
# Processing Record 995 - ukiah
# Processing Record 996 - fortuna
# Processing Record 997 - fortuna
# Processing Record 998 - fortuna
# Processing Record 999 - fortuna
# Processing Record 1000 - west wendover
# Processing Record 1001 - west wendover
# Processing Record 1002 - west wendover
# Processing Record 1003 - west wendover
# Processing Record 1004 - elko
# Processing Record 1005 - elko
# Processing Record 1006 - elko
# Processing Record 1007 - elko
# Processing Record 1008 - elko
# Processing Record 1009 - elko
# Processing Record 1010 - winnemucca
# Processing Record 1011 - winnemucca
# Processing Record 1012 - winnemucca
# Processing Record 1013 - winnemucca
# Processing Record 1014 - fallon
# Processing Record 1015 - fallon
# Processing Record 1016 - fallon
# Processing Record 1017 - fernley
# Processing Record 1018 - fernley
# Processing Record 1019 - sun valley
# Processing Record 1020 - sun valley
# Processing Record 1021 - susanville
# Processing Record 1022 - susanville
# Processing Record 1023 - susanville
# Processing Record 1024 - magalia
# Processing Record 1025 - magalia
# Processing Record 1026 - magalia
# Processing Record 1027 - red bluff
# Processing Record 1028 - red bluff
# Processing Record 1029 - red bluff
# Processing Record 1030 - red bluff
# Processing Record 1031 - ukiah
# Processing Record 1032 - fortuna
# Processing Record 1033 - fortuna
# Processing Record 1034 - fortuna
# Processing Record 1035 - fortuna
# Processing Record 1036 - fortuna
# Processing Record 1037 - west wendover
# Processing Record 1038 - west wendover
# Processing Record 1039 - west wendover
# Processing Record 1040 - west wendover
# Processing Record 1041 - elko
# Processing Record 1042 - elko
# Processing Record 1043 - elko
# Processing Record 1044 - elko
# Processing Record 1045 - elko
# Processing Record 1046 - elko
# Processing Record 1047 - winnemucca
# Processing Record 1048 - winnemucca
# Processing Record 1049 - winnemucca
# Processing Record 1050 - winnemucca
# Processing Record 1051 - winnemucca
# Processing Record 1052 - winnemucca
# Processing Record 1053 - fernley
# Processing Record 1054 - fernley
# Processing Record 1055 - fernley
# Processing Record 1056 - sun valley
# Processing Record 1057 - susanville
# Processing Record 1058 - susanville
# Processing Record 1059 - susanville
# Processing Record 1060 - susanville
# Processing Record 1061 - susanville
# Processing Record 1062 - magalia
# Processing Record 1063 - red bluff
# Processing Record 1064 - anderson
# Processing Record 1065 - anderson
# Processing Record 1066 - redding
# Processing Record 1067 - redding
# Processing Record 1068 - fortuna
# Processing Record 1069 - fortuna
# Processing Record 1070 - fortuna
# Processing Record 1071 - fortuna
# Processing Record 1072 - fortuna
# Processing Record 1073 - fortuna
# Processing Record 1074 - west wendover
# Processing Record 1075 - west wendover
# Processing Record 1076 - west wendover
# Processing Record 1077 - west wendover
# Processing Record 1078 - elko
# Processing Record 1079 - elko
# Processing Record 1080 - elko
# Processing Record 1081 - elko
# Processing Record 1082 - elko
# Processing Record 1083 - elko
# Processing Record 1084 - winnemucca
# Processing Record 1085 - winnemucca
# Processing Record 1086 - winnemucca
# Processing Record 1087 - winnemucca
# Processing Record 1088 - winnemucca
# Processing Record 1089 - winnemucca
# Processing Record 1090 - winnemucca
# Processing Record 1091 - fernley
# Processing Record 1092 - fernley
# Processing Record 1093 - susanville
# Processing Record 1094 - susanville
# Processing Record 1095 - susanville
# Processing Record 1096 - susanville
# Processing Record 1097 - susanville
# Processing Record 1098 - susanville
# Processing Record 1099 - anderson
# Processing Record 1100 - anderson
# Processing Record 1101 - shasta lake
# Processing Record 1102 - shasta lake
# Processing Record 1103 - redding
# Processing Record 1104 - redding
# Processing Record 1105 - arcata
# Processing Record 1106 - arcata
# Processing Record 1107 - arcata
# Processing Record 1108 - eureka
# Processing Record 1109 - eureka
# Processing Record 1110 - eureka
# Processing Record 1111 - west wendover
# Processing Record 1112 - west wendover
# Processing Record 1113 - west wendover
# Processing Record 1114 - west wendover
# Processing Record 1115 - elko
# Processing Record 1116 - elko
# Processing Record 1117 - elko
# Processing Record 1118 - elko
# Processing Record 1119 - elko
# Processing Record 1120 - elko
# Processing Record 1121 - winnemucca
# Processing Record 1122 - winnemucca
# Processing Record 1123 - winnemucca
# Processing Record 1124 - winnemucca
# Processing Record 1125 - winnemucca
# Processing Record 1126 - winnemucca
# Processing Record 1127 - winnemucca
# Processing Record 1128 - winnemucca
# Processing Record 1129 - susanville
# Processing Record 1130 - susanville
# Processing Record 1131 - susanville
# Processing Record 1132 - susanville
# Processing Record 1133 - susanville
# Processing Record 1134 - susanville
# Processing Record 1135 - susanville
# Processing Record 1136 - shasta lake
# Processing Record 1137 - shasta lake
# Processing Record 1138 - shasta lake
# Processing Record 1139 - shasta lake
# Processing Record 1140 - shasta lake
# Processing Record 1141 - shasta lake
# Processing Record 1142 - arcata
# Processing Record 1143 - arcata
# Processing Record 1144 - arcata
# Processing Record 1145 - arcata
# Processing Record 1146 - eureka
# Processing Record 1147 - eureka
# Processing Record 1148 - west wendover
# Processing Record 1149 - west wendover
# Processing Record 1150 - west wendover
# Processing Record 1151 - elko
# Processing Record 1152 - elko
# Processing Record 1153 - elko
# Processing Record 1154 - elko
# Processing Record 1155 - elko
# Processing Record 1156 - elko
# Processing Record 1157 - elko
# Processing Record 1158 - winnemucca
# Processing Record 1159 - winnemucca
# Processing Record 1160 - winnemucca
# Processing Record 1161 - winnemucca
# Processing Record 1162 - winnemucca
# Processing Record 1163 - winnemucca
# Processing Record 1164 - winnemucca
# Processing Record 1165 - winnemucca
# Processing Record 1166 - susanville
# Processing Record 1167 - susanville
# Processing Record 1168 - susanville
# Processing Record 1169 - susanville
# Processing Record 1170 - susanville
# Processing Record 1171 - susanville
# Processing Record 1172 - susanville
# Processing Record 1173 - altamont
# Processing Record 1174 - shasta lake
# Processing Record 1175 - shasta lake
# Processing Record 1176 - shasta lake
# Processing Record 1177 - shasta lake
# Processing Record 1178 - shasta lake
# Processing Record 1179 - arcata
# Processing Record 1180 - arcata
# Processing Record 1181 - arcata
# Processing Record 1182 - arcata
# Processing Record 1183 - eureka
# Processing Record 1184 - eureka
# Processing Record 1185 - west wendover
# Processing Record 1186 - west wendover
# Processing Record 1187 - twin falls
# Processing Record 1188 - twin falls
# Processing Record 1189 - elko
# Processing Record 1190 - elko
# Processing Record 1191 - elko
# Processing Record 1192 - elko
# Processing Record 1193 - elko
# Processing Record 1194 - winnemucca
# Processing Record 1195 - winnemucca
# Processing Record 1196 - winnemucca
# Processing Record 1197 - winnemucca
# Processing Record 1198 - winnemucca
# Processing Record 1199 - winnemucca
# Processing Record 1200 - winnemucca
# Processing Record 1201 - winnemucca
# Processing Record 1202 - winnemucca
# Processing Record 1203 - susanville
# Processing Record 1204 - susanville
# Processing Record 1205 - susanville
# Processing Record 1206 - susanville
# Processing Record 1207 - susanville
# Processing Record 1208 - altamont
# Processing Record 1209 - altamont
# Processing Record 1210 - altamont
# Processing Record 1211 - altamont
# Processing Record 1212 - klamath falls
# Processing Record 1213 - ashland
# Processing Record 1214 - ashland
# Processing Record 1215 - ashland
# Processing Record 1216 - ashland
# Processing Record 1217 - arcata
# Processing Record 1218 - arcata
# Processing Record 1219 - arcata
# Processing Record 1220 - arcata
# Processing Record 1221 - eureka
# Processing Record 1222 - burley
# Processing Record 1223 - twin falls
# Processing Record 1224 - twin falls
# Processing Record 1225 - twin falls
# Processing Record 1226 - twin falls
# Processing Record 1227 - elko
# Processing Record 1228 - elko
# Processing Record 1229 - elko
# Processing Record 1230 - elko
# Processing Record 1231 - winnemucca
# Processing Record 1232 - winnemucca
# Processing Record 1233 - winnemucca
# Processing Record 1234 - winnemucca
# Processing Record 1235 - winnemucca
# Processing Record 1236 - winnemucca
# Processing Record 1237 - winnemucca
# Processing Record 1238 - winnemucca
# Processing Record 1239 - winnemucca
# Processing Record 1240 - winnemucca
# Processing Record 1241 - susanville
# Processing Record 1242 - susanville
# Processing Record 1243 - altamont
# Processing Record 1244 - altamont
# Processing Record 1245 - altamont
# Processing Record 1246 - altamont
# Processing Record 1247 - altamont
# Processing Record 1248 - altamont
# Processing Record 1249 - klamath falls
# Processing Record 1250 - ashland
# Processing Record 1251 - ashland
# Processing Record 1252 - ashland
# Processing Record 1253 - grants pass
# Processing Record 1254 - grants pass
# Processing Record 1255 - grants pass
# Processing Record 1256 - grants pass
# Processing Record 1257 - arcata
# Processing Record 1258 - arcata

# %%
city_data_df_807 = pd.DataFrame(city_data)
print(city_data_df_807)
# Out:
#                        City  Latitude  Longitude  Max Temperature  Humidity  \
# 0         fortuna foothills      32.0     -114.0            86.00        12
# 1     san luis rio colorado      32.0     -114.3            86.00        12
# 2         estacion coahuila      32.0     -114.6            86.00        12
# 3         estacion coahuila      32.0     -114.9            86.00        12
# 4         estacion coahuila      32.0     -115.2            81.16        18
# ...                     ...       ...        ...              ...       ...
# 1253            grants pass      41.9     -123.6            58.41        82
# 1254            grants pass      41.9     -123.9            58.30        82
# 1255            grants pass      41.9     -124.2            57.78        82
# 1256                 arcata      41.9     -124.5            57.99        82
# 1257                 arcata      41.9     -124.8            58.14        59
#
#       Cloudiness  Wind Speed        Date
# 0              1        3.36  2020-08-07
# 1              1        3.36  2020-08-07
# 2              1        3.36  2020-08-07
# 3              1        3.36  2020-08-07
# 4              0        5.41  2020-08-07
# ...          ...         ...         ...
# 1253           1       12.75  2020-08-07
# 1254           1       12.75  2020-08-07
# 1255           1       12.75  2020-08-07
# 1256           1       12.75  2020-08-07
# 1257           1        5.82  2020-08-07
#
# [1258 rows x 8 columns]

# %%
city_data_df_807.to_json(r'C:\Users\rona_\Desktop\Aug07_3.json',orient="records")

# %%
city_data_df_807.to_csv(r'C:\Users\rona_\Desktop\Aug07_3.csv')

# %%
three_days_ago = datetime.date(2011,3,1) - datetime.timedelta(days=3)
three_days_ago
# Out:
# datetime.date(2011, 2, 26)
